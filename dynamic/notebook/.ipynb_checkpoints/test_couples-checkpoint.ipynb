# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../process_results/atomic_types.csv', sep=';')
df['ram-g'] = df.apply(lambda x: x['ram-k'] / 1000000.0, axis=1)

df.head()
# Out:
#    procesingtime-s   ram-k  swaps  tatomics  tlinks  tports  vatomics  \
# 0                3  290460      0         1       1       2      1002
# 1                7  459464      0        51       1       2      1002
# 2               11  608472      0       101       1       2      1002
# 3               15  726200      0       151       1       2      1002
# 4               19  978872      0       201       1       2      1002
#
#    vcoupled  vlinks     ram-g
# 0         0       0  0.290460
# 1         0       0  0.459464
# 2         0       0  0.608472
# 3         0       0  0.726200
# 4         0       0  0.978872

# %%
#sns.barplot(x='reaction_amout', y='ram_gb', data=df)
df.plot(x='tatomics', y='ram-g')
plt.show()

# %%
df.plot(x='tatomics', y='procesingtime-s')
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, vmin=0.0, vmax=1.0)
plt.show()
